# %% [markdown]
# #MAJOR DATA ANALYTICS PROJECT
# ##Seasonal Agriculture Performance Data Analytics
# **Domain:** Agriculture
# **Project Theme:** Seasonal Agriculture Performance Data Analytics
# **Tools:** Python,Matplotlib,Numpy,Seaborn
# ## Primary Goal
#
# To analyze agricultural performance across different seasons and identify meaningful patterns, trends, relationships, and variations in the available data.
# The analysis aims to understand how seasonal conditions influence agricultural outcomes and derive evidence-based insights from the dataset.

# %% [markdown]
# ##1. Problem Statement
#
# Agricultural activities are influenced by seasonal variations in environmental conditions, farming practices, resource availability and market conditions. As a result, agricultural performance may differ from one season to another.
#
# However, raw agricultural data does not clearly explain how agricultural performance changes across seasons or what patterns can be observed in different seasonal conditions.
#
# The problem is to analyze the given agricultural dataset and investigate seasonal differences in agricultural performance by identifying meaningful patterns, trends, relationships and variations within the available data.
#
# ##2. Project Objectives
#
# - Explore and understand the dataset.
# - Clean and prepare the data for analysis.
# - Examine how agricultural performance varies across seasons.
# - Identify important seasonal patterns and trends.
# - Investigate relationships between seasonal conditions and agricultural outcomes.
# - Compare relevant groups within different seasons.
# - Identify significant differences or unusual patterns.
# - Apply appropriate statistical and visualization techniques.
# - Interpret findings based on evidence from the dataset.
# - Develop meaningful conclusions and data-driven recommendations.
#
# ##3. Dataset
#
# The dataset captures agricultural activities across diverse seasons, geographical regions, and farming conditions. It encompasses key information related to cultivation practices, environmental factors, crop output, resource utilization, and economic performance.
#
# This dataset serves as the foundation for examining seasonal variations in agricultural performance and uncovering significant patterns, trends, relationships, and variations within the available data.
#
# ## Dataset Information
#
# **Dataset File:** seasonal_agriculture_performance_dataset.csv

# %%
# Import required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set_theme(style="whitegrid")
pd.set_option("display.max_columns",None)
pd.set_option("display.float_format", lambda x:f"{x:,.2f}")

# %%
#loading the datset
import pandas as pd

df = pd.read_csv('/content/seasonal_agriculture_performance_dataset.csv')
print("Data set is loaded successfully")
# Out:
# Data set is loaded successfully

# %% [markdown]
# ##4.Early Dataset Understanding
#
# The dataset is examined to understand its overall structure, dimensions, variables, and data types.

# %%
#Data Shape (Number of rows and columns)

rows, columns = df.shape

print("Number of Rows:", rows)
print("Number of Columns:", columns)
# Out:
# Number of Rows: 4000
# Number of Columns: 28

# %% [markdown]
# ##Primary Data Analysis

# %%
#Top 5 Rows
df.head()
# Out:
#    Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 0  SF10001  Andhra Pradesh    Rajkot   Wheat  Kharif                0.53
# 1  SF10002     Maharashtra  Nalgonda   Maize  Kharif                6.53
# 2  SF10003       Telangana  Warangal  Pulses    Rabi                4.86
# 3  SF10004       Telangana    Indore    Rice  Kharif                4.50
# 4  SF10005       Karnataka  Ludhiana   Maize    Zaid                4.21
#
#    Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  Soil_pH  \
# 0       486.40              24.30         69.10                5.80     7.14
# 1       855.40              25.70         78.40                5.10     5.20
# 2       455.60              23.90         56.40               10.30     5.82
# 3       753.20              29.70         65.20                6.30     5.98
# 4       101.60              34.10         55.20                6.50     6.90
#
# ...

# %%
#Bottom 5 rows
df.tail()
# Out:
#       Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 3995  SF13996       Karnataka    Rajkot   Wheat  Kharif                4.72
# 3996  SF13997       Karnataka   Krishna  Chilli  Kharif                8.77
# 3997  SF13998  Andhra Pradesh     Erode  Pulses    Zaid               10.47
# 3998  SF13999          Punjab  Warangal  Cotton  Kharif                1.73
# 3999  SF14000          Punjab    Nashik   Wheat  Kharif                3.31
#
#       Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  \
# 3995       865.40              27.30         51.40                6.30
# 3996       947.50              29.20         85.50                6.10
# 3997        80.00              35.40         68.50                8.60
# 3998       475.00              28.20         61.70                6.40
# 3999       984.30              25.80         77.20                5.90
#
#       Soil_pH  Soil_Moisture_pct  Nitrogen_kg_ha  Phosphorus_kg_ha  \
# ...

# %%
#Random Sample of Records
df.sample(5,random_state=42)
# Out:
#       Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 555   SF10556  Andhra Pradesh    Nashik  Chilli    Rabi                7.94
# 3491  SF13492          Punjab  Warangal   Wheat  Kharif               12.44
# 527   SF10528     Maharashtra    Indore  Cotton  Kharif                6.35
# 3925  SF13926  Madhya Pradesh    Nashik   Wheat    Rabi               12.52
# 2989  SF12990         Gujarat    Rajkot  Chilli    Rabi               13.98
#
#       Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  \
# 555        456.80              25.30         47.70                7.60
# 3491       601.90              27.20         60.20                8.30
# 527      1,213.70              26.30         73.60                7.10
# 3925       374.00              17.90         59.70                9.40
# 2989       197.80              19.00         55.80                9.20
#
#       Soil_pH  Soil_Moisture_pct  Nitrogen_kg_ha  Phosphorus_kg_ha  \
# ...

# %%
#column names
c_names=df.columns.tolist()
print(c_names)
# Out:
# ['Farm_ID', 'State', 'District', 'Crop', 'Season', 'Farm_Area_Hectares', 'Rainfall_mm', 'Avg_Temperature_C', 'Humidity_pct', 'Sunlight_Hours_Day', 'Soil_pH', 'Soil_Moisture_pct', 'Nitrogen_kg_ha', 'Phosphorus_kg_ha', 'Potassium_kg_ha', 'Irrigation_Method', 'Fertilizer_kg_ha', 'Pesticide_Litre_ha', 'Seed_Quality_Score', 'Yield_Tonnes_Ha', 'Production_Tonnes', 'Market_Price_INR_Tonne', 'Total_Cost_INR', 'Revenue_INR', 'Profit_INR', 'Water_Used_m3', 'Water_Efficiency_t_per_1000m3', 'Disease_Pest_Risk_pct']

# %%
#Data sets and non -null Counts
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Farm_ID                        4000 non-null   object
#  1   State                          4000 non-null   object
#  2   District                       4000 non-null   object
#  3   Crop                           4000 non-null   object
#  4   Season                         4000 non-null   object
#  5   Farm_Area_Hectares             4000 non-null   float64
#  6   Rainfall_mm                    3952 non-null   float64
#  7   Avg_Temperature_C              4000 non-null   float64
#  8   Humidity_pct                   4000 non-null   float64
#  9   Sunlight_Hours_Day             4000 non-null   float64
#  10  Soil_pH                        4000 non-null   float64
#  11  Soil_Moisture_pct              3960 non-null   float64
# ...

# %%
#Statistical Numerical Summary
df.describe()
# Out:
#        Farm_Area_Hectares  Rainfall_mm  Avg_Temperature_C  Humidity_pct  \
# count            4,000.00     3,952.00           4,000.00      4,000.00
# mean                 7.89       601.15              26.82         63.21
# std                  4.22       288.93               3.82         11.96
# min                  0.50        80.00              16.20         25.00
# 25%                  4.26       370.20              23.90         54.77
# 50%                  7.89       582.00              26.90         63.00
# 75%                 11.65       834.95              29.60         71.90
# max                 15.00     1,395.20              39.70         95.00
#
#        Sunlight_Hours_Day  Soil_pH  Soil_Moisture_pct  Nitrogen_kg_ha  \
# count            4,000.00 4,000.00           3,960.00        4,000.00
# mean                 7.32     6.70              26.51          120.25
# std                  1.12     0.64               6.71           31.22
# ...

# %%
#Summary of catagories
# Categorical Summary with statistics as rows

categorical_columns = df.select_dtypes(include=['object', 'category']).columns

categorical_summary = df[categorical_columns].describe().T

categorical_summary = categorical_summary.T

categorical_summary
# Out:
#         Farm_ID           State  District  Crop  Season Irrigation_Method
# count      4000            4000      4000  4000    4000              4000
# unique     4000               8        10     8       3                 4
# top     SF13984  Andhra Pradesh  Ludhiana  Rice  Kharif             Flood
# freq          1             529       427   690    1779              1310

# %% [markdown]
# ##5.Data Quality Analysis

# %%
# Display only columns with missing values

missing_analysis = pd.DataFrame({
    "Missing Count": df.isnull().sum(),
    "Missing Percent": (df.isnull().sum() / len(df)) * 100
})

missing_analysis = missing_analysis[missing_analysis["Missing Count"] > 0]

display(missing_analysis)
# Out:
#                    Missing Count  Missing Percent
# Rainfall_mm                   48             1.20
# Soil_Moisture_pct             40             1.00
# Yield_Tonnes_Ha               32             0.80

# %%
# Visualize Missing Values

missing_values = df.isnull().sum()
missing_values = missing_values[missing_values > 0]

plt.figure(figsize=(10, 6))

sns.barplot(
    x=missing_values.values,
    y=missing_values.index
)

plt.title("Missing Values by Column")
plt.xlabel("Missing Count")
plt.ylabel("Column Name")
plt.tight_layout()
plt.show()
